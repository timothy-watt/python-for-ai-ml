# %% [markdown]
# # 📘 Python for AI/ML — Table of Contents
#
# ### *A Complete Learning Journey: From Absolute Beginner to AI/ML Practitioner*
#
# ---
#
# > **How to use this notebook:**
# > Click any **Open in Colab** badge below to open that chapter directly in Google Colab.
# > Use **File → Save a copy in Drive** inside Colab to keep your own editable version.
# > All chapter notebooks are self-contained — you can start any chapter independently.
#
# ---
#
# 🔁 **Dataset note:** All chapters use the [Stack Overflow 2025 Developer Survey](https://raw.githubusercontent.com/timothy-watt/python-for-ai-ml/main/data/so_survey_2025_curated.csv).
# The dataset loads automatically in each notebook from GitHub — no download or Drive mounting required.

# %% [markdown]
# ## 🗺️ The Learning Journey
#
# ```
# ┌─────────────────────────────────────────────────────────────────────┐
# │                     PYTHON FOR AI/ML                                │
# │                   Three-Part Learning Arc                           │
# ├──────────────────────┬──────────────────────┬───────────────────────┤
# │   PART 1             │   PART 2             │   PART 3              │
# │   Core Python        │   Data Science       │   ML & AI             │
# │   Fundamentals       │   Foundations        │                       │
# │                      │                      │                       │
# │   Chapter 0          │   Chapter 3          │   Chapter 5           │
# │   Orientation        │   NumPy & Pandas     │   SciPy & Stats       │
# │                      │                      │                       │
# │   Chapter 1          │   Chapter 4          │   Chapter 6           │
# │   Python Basics      │   Visualization      │   Scikit-learn ML     │
# │                      │                      │                       │
# │   Chapter 2          │                      │   Chapter 7           │
# │   Intermediate       │                      │   Deep Learning       │
# │   Python             │                      │   PyTorch/Keras/TF    │
# │                      │                      │                       │
# │                      │                      │   Chapter 8           │
# │                      │                      │   NLP & Transformers  │
# │                      │                      │                       │
# │                      │                      │   Chapter 9           │
# │                      │                      │   Best Practices      │
# │                      │                      │   & Deployment        │
# ├──────────────────────┴──────────────────────┴───────────────────────┤
# │  🧵 PROJECT THREAD: Stack Overflow 2025 Developer Survey            │
# │  Salary Prediction → Role Classification → Clustering → NLP         │
# └─────────────────────────────────────────────────────────────────────┘
# ```
#
# **Estimated time investment:**
# | Part | Chapters | Estimated Hours |
# |------|----------|-----------------|
# | Part 1 — Core Python Fundamentals | Ch 0, 1, 2 | 15–20 hrs |
# | Part 2 — Data Science Foundations | Ch 3, 4 | 10–15 hrs |
# | Part 3 — Machine Learning & AI | Ch 5, 6, 7, 8, 9 | 35–45 hrs |
# | **Total** | | **~60–80 hrs** |

# %% [markdown]
# ---
#
# ## 📗 Part 1 — Core Python Fundamentals
#
# > **Goal:** Build a complete, solid foundation in Python from the ground up.
# > No prior programming experience assumed. Pure Python — no external libraries until Part 2.
# > By the end of Part 1, you will be writing functions, handling files, managing errors,
# > and building your own classes with confidence.
#
# ---
#
# ### 📓 Chapter 0 — Orientation & Setup
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH00_Orientation_and_Setup.ipynb)
#
# **What's covered:** Google Colab interface · Mounting Google Drive · GPU/TPU setup ·
# Installing packages with `!pip install` · Introducing the SO 2025 project dataset ·
# Optional local Python setup (Anaconda, VS Code, virtual environments)
#
# **Prerequisites:** None — this is where everyone starts.
#
# ---
#
# ### 📓 Chapter 1 — Python Fundamentals
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH01_Python_Fundamentals.ipynb)
#
# **What's covered:** Variables & data types · String manipulation & f-strings ·
# Booleans & comparison operators · Control flow (if/elif/else, for, while) ·
# Data structures (lists, tuples, sets, dicts) · Functions, arguments, lambda ·
# `[PROJECT]` Writing functions to summarize SO 2025 salary and language data
#
# **Prerequisites:** Chapter 0
#
# ---
#
# ### 📓 Chapter 2 — Intermediate Python
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH02_Intermediate_Python.ipynb)
#
# **What's covered:** Modules & packages · File I/O & the `with` statement ·
# CSV & JSON handling · Error & exception handling · Object-Oriented Programming ·
# Classes, inheritance, dunder methods · OOP → scikit-learn bridge ·
# List/dict comprehensions · Generators · Decorators · Context managers ·
# `[PROJECT]` Building a `SurveyLoader` class for the SO 2025 dataset
#
# **Prerequisites:** Chapter 1

# %% [markdown]
# ---
#
# ## 📘 Part 2 — Data Science Foundations
#
# > **Goal:** Master the Python data science stack — NumPy, Pandas, Matplotlib, and Seaborn.
# > The SO 2025 dataset is loaded, fully cleaned, and comprehensively visualized in this part.
# > By the end of Part 2, you will be fluent in the tools every data scientist uses daily.
#
# ---
#
# ### 📓 Chapter 3 — NumPy & Pandas
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH03_NumPy_and_Pandas.ipynb)
#
# **What's covered:** NumPy arrays · Indexing, slicing, broadcasting, ufuncs · Linear algebra ·
# Random number generation · Pandas Series & DataFrames · Selection with `.loc` / `.iloc` ·
# Data cleaning (missing values, duplicates, dtypes) · Aggregation & groupby ·
# `apply()` vs vectorized operations (with `%timeit` benchmark) · Merge & join ·
# `[PROJECT]` Loading & cleaning SO 2025 — salary outliers, multi-value language columns
#
# **Prerequisites:** Chapter 2
#
# ---
#
# ### 📓 Chapter 4 — Data Visualization
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH04_Data_Visualization.ipynb)
#
# **What's covered:** Matplotlib line, scatter, and bar plots · Customization (titles, labels, style) ·
# Subplots & figure layout · Seaborn statistical plots (histogram, box, violin) ·
# Relational & categorical plots · Heatmaps & correlation matrices · Pair plots ·
# FacetGrid · Plotly Express interactive visualization ·
# `[PROJECT]` Full EDA visualization suite — SO 2025 salary, languages, AI tools, geography
#
# **Prerequisites:** Chapter 3

# %% [markdown]
# ---
#
# ## 📙 Part 3 — Machine Learning & Artificial Intelligence
#
# > **Goal:** Build, train, evaluate, and deploy real ML and AI models using the complete
# > modern Python AI/ML stack. The SO 2025 dataset drives all examples — salary regression,
# > developer role classification, clustering, and AI sentiment NLP from one source.
# >
# > ⚠️ **GPU recommended for Chapters 7 & 8.**
# > In Colab: `Runtime → Change Runtime Type → T4 GPU`
#
# ---
#
# ### 📓 Chapter 5 — SciPy & Statistical Computing
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH05_SciPy_Statistical_Computing.ipynb)
#
# **What's covered:** SciPy ecosystem overview · `scipy.stats` — distributions & hypothesis tests ·
# `scipy.optimize` — root finding & curve fitting · `scipy.interpolate` · `scipy.signal` intro ·
# NumPy structured & masked arrays ·
# `[PROJECT]` Hypothesis tests on SO 2025 salary by education, role, and country
#
# **Prerequisites:** Chapter 4
#
# ---
#
# ### 📓 Chapter 6 — Machine Learning with Scikit-learn
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH06_Machine_Learning_Scikit_Learn.ipynb)
#
# **What's covered:** ML concepts · Supervised vs unsupervised · Bias-variance trade-off ·
# **Data leakage** (what it is, why it destroys models, how Pipelines prevent it) ·
# Feature scaling, encoding, imputation, selection · **scikit-learn Pipelines** (full section) ·
# Linear & logistic regression · Decision trees & random forests · SVM · KNN · XGBoost intro ·
# K-Means, DBSCAN, PCA, t-SNE · Full evaluation suite (classification & regression metrics) ·
# Cross-validation · Hyperparameter tuning (Grid Search, Random Search, Optuna intro) ·
# `[PROJECT]` Full salary prediction pipeline + developer role classifier on SO 2025
#
# **Prerequisites:** Chapter 5
#
# ---
#
# ### 📓 Chapter 7 — Deep Learning: PyTorch · Keras 3 · TensorFlow
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH07_Deep_Learning_PyTorch_Keras_TensorFlow.ipynb)
#
# **What's covered:** Deep learning concepts · Neural network architecture ·
# **2025 Framework Landscape** — why PyTorch won, Keras 3's role, TF's current place ·
# **PyTorch (PRIMARY)** — tensors, autograd, `nn.Module`, DataLoaders, full training loop ·
# **Keras 3 (companion)** — same model, less boilerplate, running on PyTorch backend ·
# CNNs · RNNs/LSTMs · Regularization · Transfer learning ·
# **TensorFlow (context)** — reading legacy code, TFX/TFLite ecosystem, migration patterns ·
# `[PROJECT]` PyTorch salary predictor + Keras 3 rebuild + scikit-learn benchmark comparison
#
# **⚠️ Enable GPU:** `Runtime → Change Runtime Type → T4 GPU`
#
# **Prerequisites:** Chapter 6
#
# ---
#
# ### 📓 Chapter 8 — Natural Language Processing & Transformers
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH08_Natural_Language_Processing.ipynb)
#
# **What's covered:** NLP fundamentals · Text preprocessing (tokenization, stopwords, stemming) ·
# Regex for text cleaning · Bag-of-Words · TF-IDF · Word embeddings (conceptual) ·
# Text classification with Naive Bayes & SVM · spaCy pipelines ·
# **Hugging Face Transformers** — transformer architecture, `pipeline()` API,
# pre-trained BERT-style models, fine-tuning walkthrough ·
# `[PROJECT]` Developer role classification + AI tool sentiment analysis on SO 2025 text fields
#
# **⚠️ Enable GPU:** `Runtime → Change Runtime Type → T4 GPU`
#
# **Prerequisites:** Chapter 7
#
# ---
#
# ### 📓 Chapter 9 — Best Practices, Workflow & Deployment
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH09_Best_Practices_Project_Workflow.ipynb)
#
# **What's covered:** Reproducibility · Git & GitHub for data science · Notebook version control ·
# PEP 8 & clean code · Docstrings · Unit testing with pytest · Virtual environments ·
# REST APIs with `requests` · SQL with `sqlite3` + `pandas.read_sql` · Cloud storage ·
# **Model saving & serving** — `joblib`, `.pt`, FastAPI salary prediction endpoint ·
# Full DS project workflow · **Bias audit** on salary predictions across gender & geography ·
# Responsible AI · Data privacy & GDPR basics ·
# `[PROJECT]` End-to-end SO 2025 review: Git → saved model → FastAPI endpoint → bias audit
#
# **Prerequisites:** Chapter 8

# %% [markdown]
# ---
#
# ## 📎 Appendices
#
# ---
#
# ### 📓 Appendix A — Python Quick Reference Card
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH_Appendix_A_Reference_Card.ipynb)
#
# Syntax cheatsheet · Built-in functions · Common patterns · Data structure methods ·
# NumPy / Pandas / scikit-learn / PyTorch one-liners
#
# ---
#
# ### 📓 Appendix B — Recommended Resources & Next Steps
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH_Appendix_B_Resources.ipynb)
#
# Curated books · Courses · Communities · Competitions (Kaggle) ·
# Where to go deeper: RL, LLMs, MLOps, RAG, production systems
#
# ---
#
# ### 📓 Appendix C — Glossary
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timothy-watt/python-for-ai-ml/blob/main/CH_Appendix_C_Glossary.ipynb)
#
# Key terms from Part 1 → Part 3 · Definitions in plain English · Cross-references to chapters

# %% [markdown]
# ---
#
# ## ⚙️ Prerequisites & Recommended Background
#
# | Background | Starting Point |
# |---|---|
# | No programming experience | Start at Chapter 0 |
# | Some Python, new to data science | Start at Chapter 3 |
# | Python + data science, new to ML | Start at Chapter 6 |
# | ML background, learning deep learning | Start at Chapter 7 |
#
# **What you need:**
# - A Google account (for Colab) — free
# - An internet connection
# - No local software installation required
# - GPU access: free T4 via Google Colab · upgraded runtimes via Colab Pro (optional but helpful for Ch 7–8)
#
# **Library versions used throughout this book:**
# | Library | Version |
# |---|---|
# | Python | 3.11+ |
# | NumPy | 1.26+ |
# | Pandas | 2.2+ |
# | Matplotlib | 3.8+ |
# | Seaborn | 0.13+ |
# | scikit-learn | 1.4+ |
# | PyTorch | 2.3+ |
# | Keras | 3.3+ |
# | Hugging Face `transformers` | 4.40+ |
# | SciPy | 1.13+ |

# %% [markdown]
# ---
#
# ## 🗃️ Project Dataset: Stack Overflow 2025 Developer Survey
#
# All chapters use a single, consistent dataset — the **Stack Overflow 2025 Annual Developer Survey**.
#
# | Property | Detail |
# |---|---|
# | **Source** | [Stack Overflow Annual Developer Survey](https://survey.stackoverflow.co/) |
# | **Year** | 2025 (most current release) |
# | **Full dataset** | ~49,000 respondents · 62 questions · 314 technologies |
# | **Curated subset used in this book** | 15,000 rows · English-language respondents with salary data |
# | **License** | Open Database License (ODbL) — freely usable |
#
# **Key columns used throughout the book:**
#
# | Column | Type | Description | Used In |
# |---|---|---|---|
# | `ConvertedCompYearly` | Float | Annual salary in USD | Ch 3–7, 9 |
# | `DevType` | String (multi-value) | Developer role(s) | Ch 3, 6, 8 |
# | `LanguageHaveWorkedWith` | String (multi-value) | Programming languages used | Ch 3, 4, 6 |
# | `YearsCodePro` | Int | Years of professional coding experience | Ch 3, 5, 6, 7 |
# | `Country` | String | Respondent's country | Ch 3, 4, 5, 9 |
# | `EdLevel` | String | Highest education level | Ch 5, 6 |
# | `Employment` | String | Employment status | Ch 6 |
# | `RemoteWork` | String | Remote / hybrid / in-person | Ch 4, 6 |
# | `AIToolCurrently` | String (multi-value) | AI tools currently used | Ch 4, 8 |
# | `AITrustTeammates` | String | Trust level in AI tools | Ch 8 |
# | `AIBen` | String | Perceived benefit of AI tools | Ch 8 |
# | `OrgSize` | String | Organization size | Ch 6 |
# | `Age` | String | Age range | Ch 4, 9 |
# | `Gender` | String | Gender identity | Ch 9 (bias audit) |
#
# **Dataset access in every notebook:**
# ```python
# # This URL works in every chapter — no download or Drive mounting needed
# DATASET_URL = "https://raw.githubusercontent.com/timothy-watt/python-for-ai-ml/main/data/so_survey_2025_curated.csv"
# df = pd.read_csv(DATASET_URL)
# ```
# > 📌 Replace `https://raw.githubusercontent.com/timothy-watt/python-for-ai-ml/main` with your actual repo URL once set up.

# %% [markdown]
# ---
#
# ## 📄 Attribution & License
#
# **Book:** *Python for AI/ML — A Complete Learning Journey*
# **Dataset:** Stack Overflow 2025 Developer Survey · [survey.stackoverflow.co](https://survey.stackoverflow.co) · ODbL License
# **Platform:** Built for Google Colab · Compatible with any Jupyter environment
#
# ---
#
# *Last validated: 2025 · Library versions pinned per Chapter 0*
# *Found an issue? Open a GitHub issue in the repository.*
